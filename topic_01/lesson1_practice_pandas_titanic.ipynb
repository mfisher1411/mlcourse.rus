# %% [markdown]
# <center>
# <img src="../img/ods_stickers.jpg">

# %% [markdown]
# ## Открытый курс по машинному обучению. Сессия № 2
# </center>
# Автор материала: программист-исследователь Mail.ru Group, старший преподаватель Факультета Компьютерных Наук ВШЭ Юрий Кашницкий. Материал распространяется на условиях лицензии [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/). Можно использовать в любых целях (редактировать, поправлять и брать за основу), кроме коммерческих, но с обязательным упоминанием автора материала.

# %% [markdown]
# # <center>Тема 1. Первичный анализ данных с Pandas</center>
# ## <center>Практическое задание. Анализ данных пассажиров "Титаника"</center>
#
# **Заполните код в клетках (где написано "Ваш код здесь") и ответьте на вопросы в [веб-форме](https://goo.gl/SbRcpW).**

# %%
import numpy as np
import pandas as pd

# %matplotlib inline

# %% [markdown]
# **Считаем данные из файла в память в виде объекта Pandas.DataFrame**

# %%
data = pd.read_csv("../data/titanic_train.csv", index_col="PassengerId")

# %% [markdown]
# **Данные представлены в виде таблицы. Посмотрим на первые 5 строк:**

# %%
data.head(5)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# **Для примера отберем пассажиров, которые сели в Cherbourg (Embarked=C) и заплатили более 200 у.е. за билет (fare > 200).**
#
# Убедитесь, что Вы понимаете, как эта конструкция работает. <br>
# Если нет – посмотрите, как вычисляется выражение в квадратных в скобках.

# %%
data[(data['Embarked']=='C')&(data['Fare']>200)]
# Out:
#              Survived  Pclass  \
# PassengerId
# 119                 0       1
# 259                 1       1
# 300                 1       1
# 312                 1       1
# 378                 0       1
# 381                 1       1
# 558                 0       1
# 680                 1       1
# 701                 1       1
# 717                 1       1
# 738                 1       1
# 743                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 119                                   Baxter, Mr. Quigg Edmond    male  24.0
# 259                                           Ward, Miss. Anna  female  35.0
# 300            Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0
# 312                                 Ryerson, Miss. Emily Borie  female  18.0
# 378                                  Widener, Mr. Harry Elkins    male  27.0
# ...

# %%
data[(data["Embarked"] == "C") & (data.Fare > 200)].head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 119                 0       1
# 259                 1       1
# 300                 1       1
# 312                 1       1
# 378                 0       1
#
#                                                         Name     Sex   Age  \
# PassengerId
# 119                                 Baxter, Mr. Quigg Edmond    male  24.0
# 259                                         Ward, Miss. Anna  female  35.0
# 300          Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0
# 312                               Ryerson, Miss. Emily Borie  female  18.0
# 378                                Widener, Mr. Harry Elkins    male  27.0
#
#              SibSp  Parch    Ticket      Fare            Cabin Embarked
# PassengerId
# 119              0      1  PC 17558  247.5208          B58 B60        C
# 259              0      0  PC 17755  512.3292              NaN        C
# ...

# %% [markdown]
# **Можно отсортировать этих людей по убыванию платы за билет.**

# %%
data[(data['Embarked']=='C')&(data['Fare']>200)].sort_values(by=['Fare'], ascending=False)
# Out:
#              Survived  Pclass  \
# PassengerId
# 259                 1       1
# 680                 1       1
# 738                 1       1
# 312                 1       1
# 743                 1       1
# 119                 0       1
# 300                 1       1
# 381                 1       1
# 558                 0       1
# 701                 1       1
# 717                 1       1
# 378                 0       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 259                                           Ward, Miss. Anna  female  35.0
# 680                         Cardeza, Mr. Thomas Drake Martinez    male  36.0
# 738                                     Lesurer, Mr. Gustave J    male  35.0
# 312                                 Ryerson, Miss. Emily Borie  female  18.0
# 743                      Ryerson, Miss. Susan Parker "Suzette"  female  21.0
# ...

# %%
data[(data["Embarked"] == "C") & (data["Fare"] > 200)].sort_values(
    by="Fare", ascending=False
).head()
# Out:
#              Survived  Pclass                                   Name     Sex  \
# PassengerId
# 259                 1       1                       Ward, Miss. Anna  female
# 680                 1       1     Cardeza, Mr. Thomas Drake Martinez    male
# 738                 1       1                 Lesurer, Mr. Gustave J    male
# 312                 1       1             Ryerson, Miss. Emily Borie  female
# 743                 1       1  Ryerson, Miss. Susan Parker "Suzette"  female
#
#               Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# PassengerId
# 259          35.0      0      0  PC 17755  512.3292              NaN        C
# 680          36.0      0      1  PC 17755  512.3292      B51 B53 B55        C
# 738          35.0      0      0  PC 17755  512.3292             B101        C
# 312          18.0      2      2  PC 17608  262.3750  B57 B59 B63 B66        C
# 743          21.0      2      2  PC 17608  262.3750  B57 B59 B63 B66        C

# %% [markdown]
# **Пример создания признака.**

# %%
def age_category(age):
    """
    < 30 -> 1
    >= 30, <55 -> 2
    >= 55 -> 3
    """
    if age < 30:
        return 1
    elif age < 55:
        return 2
    else:
        return 3

# %%
age_categories = [age_category(age) for age in data.Age]

# %%
data["Age_category"] = age_categories

# %% [markdown]
# **Другой способ – через `apply`.**

# %%
data["Age_category"] = data["Age"].apply(age_category)

# %% [markdown]
# **1. Сколько мужчин / женщин находилось на борту?**
# - 412 мужчин и 479 женщин
# - 314 мужчин и 577 женщин
# - 479 мужчин и 412 женщин
# - 577 мужчин и 314 женщин

# %%
# Ваш код здесь
data['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %% [markdown]
# **2. Выведите распределение переменной `Pclass` (социально-экономический статус) и это же распределение, только для мужчин / женщин по отдельности. Сколько было мужчин 2-го класса?**
# - 104
# - 108
# - 112
# - 125

# %%
data['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# ...

# %%
data['Exited'] = data['Pclass']

# %%
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# ...

# %%
data[(data['Pclass']==2)&(data['Sex']=='male')].agg('count')
# Out:
# Survived        108
# Pclass          108
# Name            108
# Sex             108
# Age              99
# SibSp           108
# Parch           108
# Ticket          108
# Fare            108
# Cabin             6
# Embarked        108
# Age_category    108
# dtype: int64

# %%
# Ваш код здесь
data[['Pclass', 'Sex','Exited']].groupby(['Pclass','Sex']).agg('count')
# Out:
#                Exited
# Pclass Sex
# 1      female      94
#        male       122
# 2      female      76
#        male       108
# 3      female     144
#        male       347

# %%
pd.crosstab(data["Sex"], data["Pclass"])
# Out:
# Pclass    1    2    3
# Sex
# female   94   76  144
# male    122  108  347

# %%
data['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %% [markdown]
# **3. Каковы медиана и стандартное отклонение платежей (`Fare`)? Округлите до 2 десятичных знаков.**
# - Медиана – 14.45, стандартное отклонение – 49.69
# - Медиана – 15.1, стандартное отклонение – 12.15
# - Медиана – 13.15, стандартное отклонение – 35.3
# - Медиана – 17.43, стандартное отклонение – 39.1

# %%
# Ваш код здесь
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# ...

# %%
data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare  \
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200
#
#        Age_category      Exited
# count    891.000000  891.000000
# mean       1.814815    2.308642
# std        0.801995    0.836071
# min        1.000000    1.000000
# 25%        1.000000    2.000000
# 50%        2.000000    3.000000
# 75%        2.000000    3.000000
# ...

# %%
data['Fare'].agg(np.median).round(2), data['Fare'].agg(np.std).round(2)
# Out:
# (14.45, 49.69)

# %% [markdown]
# **4. Правда ли, что люди моложе 30 лет выживали чаще, чем люди старше 60 лет? Каковы доли выживших в обеих группах?**
# - 22.7% среди молодых и 40.6% среди старых
# - 40.6% среди молодых и 22.7% среди старых
# - 35.3% среди молодых и 27.4% среди старых
# - 27.4% среди молодых и 35.3% среди старых

# %%
# Ваш код здесь
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Survived      891 non-null    int64
#  1   Pclass        891 non-null    int64
#  2   Name          891 non-null    object
#  3   Sex           891 non-null    object
#  4   Age           714 non-null    float64
#  5   SibSp         891 non-null    int64
#  6   Parch         891 non-null    int64
#  7   Ticket        891 non-null    object
#  8   Fare          891 non-null    float64
#  9   Cabin         204 non-null    object
#  10  Embarked      889 non-null    object
#  11  Age_category  891 non-null    int64
#  12  Exited        891 non-null    int64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 97.5+ KB

# %%
data[data['Age'] < 30]['Age'].count(), data[data['Age'] > 60]['Age'].count()
# Out:
# (384, 22)

# %%
pd.crosstab(data["Sex"], data["Pclass"])
pd.crosstab(data['Survived'], data['Age'])
# Out:
# Age       0.42   0.67   0.75   0.83   0.92   1.00   2.00   3.00   4.00   \
# Survived
# 0             0      0      0      0      0      2      7      1      3
# 1             1      1      2      2      1      5      3      5      7
#
# Age       5.00   ...  62.00  63.00  64.00  65.00  66.00  70.00  70.50  71.00  \
# Survived         ...
# 0             0  ...      2      0      2      3      1      2      1      2
# 1             4  ...      2      2      0      0      0      0      0      0
#
# Age       74.00  80.00
# Survived
# 0             1      0
# 1             0      1
#
# [2 rows x 88 columns]

# %%
d = data[data['Age'] <30]

# %%
data[['Pclass', 'Sex','Exited']].groupby(['Pclass','Sex']).agg('count')
d[['Survived', 'Age']].groupby('Survived').agg('count')
# Out:
#           Age
# Survived
# 0         228
# 1         156

# %%
data[(data['Age'] < 30)&(data['Survived']==1)]['Survived'].count()
# Out:
# 156

# %%
(data[(data['Age'] < 30)&(data['Survived']==1)]['Survived'].count()/data[data['Age'] < 30]['Age'].count()).round(3), (data[(data['Age'] > 60)&(data['Survived']==1)]['Survived'].count()/data[data['Age'] > 60]['Age'].count()).round(3)
# Out:
# (0.406, 0.227)

# %% [markdown]
# **5. Правда ли, что женщины выживали чаще мужчин? Каковы доли выживших в обеих группах?**
# - 30.2% среди мужчин и 46.2% среди женщин
# - 35.7% среди мужчин и 74.2% среди женщин
# - 21.1% среди мужчин и 46.2% среди женщин
# - 18.9% среди мужчин и 74.2% среди женщин

# %%
# Ваш код здесь
(data[(data['Sex'] =='female')&(data['Survived']==1)]['Survived'].count()/data[data['Sex'] =='female']['Sex'].count()).round(3), (data[(data['Sex'] =='male')&(data['Survived']==1)]['Survived'].count()/data[data['Sex'] =='male']['Sex'].count()).round(3)
# Out:
# (0.742, 0.189)

# %% [markdown]
# **6. Найдите самое популярное имя среди пассажиров Титаника мужского пола?**
# - Charles
# - Thomas
# - William
# - John

# %%
data[data['Sex']=='male'].head()
# Out:
#              Survived  Pclass                            Name   Sex   Age  \
# PassengerId
# 1                   0       3         Braund, Mr. Owen Harris  male  22.0
# 5                   0       3        Allen, Mr. William Henry  male  35.0
# 6                   0       3                Moran, Mr. James  male   NaN
# 7                   0       1         McCarthy, Mr. Timothy J  male  54.0
# 8                   0       3  Palsson, Master. Gosta Leonard  male   2.0
#
#              SibSp  Parch     Ticket     Fare Cabin Embarked  Age_category  \
# PassengerId
# 1                1      0  A/5 21171   7.2500   NaN        S             1
# 5                0      0     373450   8.0500   NaN        S             2
# 6                0      0     330877   8.4583   NaN        Q             3
# 7                0      0      17463  51.8625   E46        S             2
# 8                3      1     349909  21.0750   NaN        S             1
#
#              Exited
# PassengerId
# ...

# %%
# Ваш код здесь
first_names = data[data['Sex'] == 'male']['Name'].apply(lambda full_name: 
                full_name.split(',')[1].split()[1])
first_names.value_counts().head()
# Out:
# William    35
# John       25
# George     14
# Charles    13
# Thomas     13
# Name: Name, dtype: int64

# %% [markdown]
# **7. Сравните графически распределение стоимости билетов и возраста у спасенных и у погибших. Средний возраст погибших выше, верно?**
# - Да
# - Нет

# %%
# Ваш код здесь
import matplotlib.pyplot as plt
data[data['Survived'] == 1]['Fare'].hist(color="green", 
                                         label='Survived')
data[data['Survived'] == 0]['Fare'].hist(color="red", 
                                         label='Died')
plt.title('Ticket fare for survived and died')
plt.xlabel('Pounds')
plt.ylabel('Frequency')
plt.legend();

# %%
data[data['Survived'] == 1]['Age'].hist(color="green", 
                                         label='Survived', alpha=.5)
data[data['Survived'] == 0]['Age'].hist(color="red", 
                                         label='Died', alpha=.5)
plt.title('Age for survived and died')
plt.xlabel('Years')
plt.ylabel('Frequency')
plt.legend();

# %%
import seaborn as sns
sns.boxplot(x=data['Survived'], y=data['Age'])
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>

# %%
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# ...

# %%
data[['Survived', 'Age']].groupby('Survived').mean().round(2)
# Out:
#             Age
# Survived
# 0         30.63
# 1         28.34

# %% [markdown]
# **8. Как отличается средний возраст мужчин / женщин в зависимости от класса обслуживания? Выберите верные утверждения:**
# - В среднем мужчины 1-го класса старше 40 лет
# - В среднем женщины 1-го класса старше 40 лет
# - Мужчины всех классов в среднем старше женщин того же класса
# - В среднем люди в 1 классе старше, чем во 2-ом, а те старше представителей 3-го класса

# %%
data[['Pclass','Sex', 'Age']].groupby(['Pclass', 'Sex']).mean().round(2)
# Out:
#                  Age
# Pclass Sex
# 1      female  34.61
#        male    41.28
# 2      female  28.72
#        male    30.74
# 3      female  21.75
#        male    26.51

# %%
data[['Pclass','Age']].groupby(['Pclass']).mean().round(2)
# Out:
#           Age
# Pclass
# 1       38.23
# 2       29.88
# 3       25.14

# %%
# Ваш код здесь
